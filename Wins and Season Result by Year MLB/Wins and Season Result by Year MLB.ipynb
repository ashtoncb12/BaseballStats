# %%
import plotly
import plotly.express as px
import numpy as np
import pandas as pd
import math
from sportsipy.mlb.teams import Teams
from sportsipy.mlb.teams import Team
import pybaseball as pyball
pd.options.plotting.backend = "plotly"
import time
import plotly.io as pio

# %%
wclogs = pyball.wild_card_logs()

# %%
dslogs = pyball.division_series_logs()

# %%
cslogs = pyball.lcs_logs()

# %%
wslogs = pyball.world_series_logs()

# %%
#test function for troubleshooting
def winstest(name):
    teamslist = pyball.teams()
    teamdf = teamslist.loc[(teamslist["franchID"] == name) & (teamslist["yearID"] > 1902)]
    wins_arr = []
    year_arr = []
    for i in teamdf["W"]:
        wins_arr.append(i)
    for i in teamdf["yearID"]:
        year_arr.append(i)
    return print(wins_arr), print(year_arr)

winstest("CHC")

# teamslist = pyball.teams()
# testdf = teamslist.loc[teamslist["yearID"] == 2021]
# print(testdf)
# Out:
# [82, 93, 92, 116, 107, 99, 104, 104, 92, 91, 88, 78, 73, 67, 74, 84, 75, 75, 64, 80, 83, 81, 68, 82, 85, 91, 98, 90, 84, 90, 86, 86, 100, 87, 93, 89, 84, 75, 70, 68, 74, 75, 98, 82, 69, 64, 61, 64, 62, 77, 65, 64, 72, 60, 62, 72, 74, 60, 64, 59, 82, 76, 72, 59, 87, 84, 92, 84, 83, 85, 77, 66, 75, 75, 81, 79, 80, 64, 38, 73, 71, 96, 77, 70, 76, 77, 93, 77, 77, 78, 84, 49, 73, 76, 68, 90, 67, 65, 88, 67, 88, 89, 79, 66, 85, 97, 83, 75, 71, 61, 66, 73, 97, 103, 92, 95, 84, 34, 71]
# [1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# (None, None)

# %%
#get team abbreviations
for franchise in teamslist["teamID"]:
    print(franchise)
# Out:
# BS1
# CH1
# CL1
# FW1
# NY2
# PH1
# RC1
# TRO
# WS3
# BL1
# BR1
# BR2
# BS1
# CL1
# MID
# NY2
# PH1
# TRO
# WS3
# WS4
# BL1
# BL4
# BR2
# BS1
# ELI
# NY2
# PH1
# PH2
# WS5
# BL1
# BR2
# BS1
# CH2
# HR1
# NY2
# PH1
# PH2
# BR2
# BS1
# CH2
# HR1
# KEO
# NH1
# NY2
# PH1
# PH2
# PH3
# SL1
# SL2
# WS6
# BSN
# CHN
# CN1
# HAR
# LS1
# NY3
# PHN
# SL3
# BSN
# CHN
# CN1
# HAR
# LS1
# SL3
# BSN
# CHN
# CN1
# IN1
# ML2
# PRO
# BFN
# BSN
# CHN
# CL2
# CN1
# PRO
# SR1
# TRN
# BFN
# BSN
# CHN
# CL2
# CN1
# PRO
# TRN
# WOR
# BFN
# BSN
# CHN
# CL2
# DTN
# PRO
# TRN
# WOR
# BFN
# BL2
# BSN
# CHN
# CL2
# CN2
# DTN
# LS2
# PH4
# PRO
# PT1
# SL4
# TRN
# WOR
# BFN
# BL2
# BSN
# CHN
# CL2
# CL5
# CN2
# DTN
# LS2
# NY1
# NY4
# PH4
# PHI
# PRO
# PT1
# SL4
# ALT
# BFN
# BL2
# BLU
# BR3
# BSN
# BSU
# CHN
# CHU
# CL2
# CL5
# CN2
# CNU
# DTN
# IN2
# KCU
# LS2
# MLU
# NY1
# NY4
# MIL
# MIN
# NYA
# NYN
# OAK
# PHI
# PIT
# SDN
# SEA
# SFN
# SLN
# TBA
# TEX
# TOR
# WAS
# ARI
# ATL
# BAL
# BOS
# CHA
# CHN
# CIN
# CLE
# COL
# DET
# HOU
# KCA
# LAA
# LAN
# MIA
# MIL
# MIN
# NYA
# NYN
# OAK
# PHI
# PIT
# SDN
# SEA
# SFN
# SLN
# TBA
# TEX
# TOR
# WAS

# %%
#print active franchise tags
df = pyball.teams_franchises()
for team in df["franchID"]:
    index = df.franchID[df.franchID == team].index.tolist()
    if df.active[index[0]] == "Y":
        print(team)
# Out:
# ANA
# ARI
# ATL
# BAL
# BOS
# CHC
# CHW
# CIN
# CLE
# COL
# DET
# FLA
# HOU
# KCR
# LAD
# MIL
# MIN
# NYM
# NYY
# OAK
# PHI
# PIT
# SDP
# SEA
# SFG
# STL
# TBD
# TEX
# TOR
# WSN

# %%
#get franchise tags
fran = pyball.teams_franchises()
for i in fran["franchID"]:
    print(i)
# Out:
# ALT
# ANA
# ARI
# ATH
# ATL
# BAL
# BFB
# BFL
# BLC
# BLO
# BLT
# BLU
# BNA
# BOS
# BRA
# BRD
# BRG
# BRS
# BTT
# BUF
# BWW
# CBK
# CBL
# CEN
# CFC
# CHC
# CHH
# CHP
# CHW
# CIN
# CKK
# CLE
# CLI
# CLS
# CLV
# CNA
# CNR
# COL
# COR
# CPI
# DET
# DTN
# ECK
# FLA
# HAR
# HNA
# HOU
# IBL
# IHO
# IND
# KCC
# KCN
# KCP
# KCR
# KCU
# KEK
# LAD
# LGR
# LOU
# MAN
# MAR
# MIL
# MIN
# MLA
# MLG
# MLU
# NAT
# NEW
# NHV
# NNA
# NYI
# NYM
# NYP
# NYU
# NYY
# OAK
# OLY
# PBB
# PBS
# PHA
# PHI
# PHK
# PHQ
# PIT
# PNA
# PRO
# PWS
# RES
# RIC
# ROC
# ROK
# SBS
# SDP
# SEA
# SFG
# SLI
# SLM
# SLR
# SNA
# STL
# STP
# SYR
# SYS
# TBD
# TEX
# TLM
# TOL
# TOR
# TRO
# TRT
# WAS
# WBL
# WES
# WIL
# WNA
# WNL
# WNT
# WOR
# WSN
# WST

# %%
#build a function that returns a list of years of a given series losses for a given team
def process(logs, losses_needed, weight, team, check):
    logs_team = pd.concat([logs.loc[logs["home_team"] == team], logs.loc[logs["visiting_team"] == team]])

    df = logs_team.reset_index()
    df.sort_values("date", inplace = True)
    df.reset_index(inplace = True, drop = True)
    years = []
    for i in range(0, len(df)):
        year_string = str(df["date"][i])
        year_concat = year_string[:4]
        years.append(int(year_concat))
    years = [*set(years)]
    series_index = {"Year" : [], "Game Index" : []}
    for year in years:
        series_index["Year"].append(str(year))
        games_arr = []
        for game in df["date"]:
            if str(game)[:4] == str(year):
                games_arr.append(df.date[df.date == game].index.tolist())
        series_index["Game Index"].append(games_arr)
    count = 0
    
    tlosslist = [[], weight]
    
    lossdict = {"Year" : [], "Weight" : weight}
    winlist = [[], weight]
    for series in series_index["Game Index"]:
        losses = 0
        for i in series:
            if df["home_team"][i[0]] == team:
                if df["visiting_score"][i[0]] > df["home_score"][i[0]]:
                    losses += 1
            else:
                if df["home_score"][i[0]] > df["visiting_score"][i[0]]:
                    losses += 1
            if losses == losses_needed:
                tlosslist[0].append(series_index["Year"][count])

            else:
                winlist[0].append(series_index["Year"][count])

        count += 1  

    if check:
        winlistint = [*set(winlist[0])]
        winlist[0].clear()
        for i in winlistint:
            winlist[0].append(str(i))
        winlist[0] = [x for x in winlist[0] if x not in tlosslist[0]]
    
    if check:
        return winlist

    else:
        return tlosslist


def wclosses(team):
    #logs = pyball.wild_card_logs()
    logs = wclogs
    return process(logs, 1, 1, team, False)

def dslosses(team):
    logs = dslogs
    #logs = pyball.division_series_logs()
    return process(logs, 3, 2, team, False)

def lcslosses(team):
    logs = cslogs
    #logs = pyball.lcs_logs()
    return process(logs, 4, 3, team, False)

def wslosses(team):
    logs = wslogs
    #logs = pyball.world_series_logs()
    return process(logs, 4, 4, team, False)

def wswins(team):
    logs = wslogs
    #logs = pyball.world_series_logs()
    return process(logs, 4, 5, team, True)
#work with this some more
def franchise_beginning(team):
    for i in range(1903, 2022):
        try:
            teams = pyball.schedule_and_record(i, team)
            return i
        except:
            continue   

def wins(name):
    teamslist = pyball.teams()
    teamdf = teamslist.loc[(teamslist["franchID"] == name) & (teamslist["yearID"] > 1902)]
    wins_arr = []
    year_arr = []
    for i in teamdf["W"]:
        wins_arr.append(i)
    for i in teamdf["yearID"]:
        year_arr.append(i)
    return wins_arr, year_arr

def year_and_weight(team, beginning):
    years = []
    for i in range(beginning, 2022):
        years.append(str(i))
    wclist = wclosses(team)[0]
    dslist = dslosses(team)[0]
    lcslist = lcslosses(team)[0]
    wslosslist = wslosses(team)[0]
    wswinslist = wswins(team)[0]
    postseasonlist = wclist + dslist + lcslist + wslosslist + wswinslist
    missed_playoffs = [x for x in years if x not in postseasonlist]
    
    weightslist = []
    for year in years:
        if year in missed_playoffs:
            weightslist.append("Missed Playoffs")
        elif year in wclist:
            weightslist.append("Lost in WC")
        elif year in dslist:
            weightslist.append("Lost in DS")
        elif year in lcslist:
            weightslist.append("Lost in CS")
        elif year in wslosslist:
            weightslist.append("Lost in WS")
        else:
            weightslist.append("Won WS")
    return weightslist

# %%
def create(teamabbr, teamname):
    d = {"Year" : [], "Wins" : [], "Result" : []}
    wins_arr, year_arr = wins(teamabbr)
    d["Wins"] = wins_arr
    d["Year"] = year_arr
    for weight in year_and_weight(teamabbr, year_arr[0]):
        d["Result"].append(weight)

    colordict = {"Result" : ["Missed Playoffs", "Lost in WC", "Lost in DS", "Lost in CS", "Lost in WS", "Won WS"],
             "Color" : ["rgba(0, 0, 0, 1)", "rgba(255, 156, 156, 1)", "rgba(120, 125, 55, 1)", "rgb(205, 127, 50)", "rgba(150, 150, 150, 1)", "rgba(255, 216, 0, 1)"]}
    colors = []
    for result in d["Result"]:
        result_index = colordict["Result"].index(result)
        result_color = colordict["Color"][result_index]
        if result_color in colors:
            continue
        if result == "Missed Playoffs":
            colors.append(colordict["Color"][0])
        if result == "Lost in WC":
            colors.append(colordict["Color"][1])
        if result == "Lost in DS":
            colors.append(colordict["Color"][2])
        if result == "Lost in CS":
            colors.append(colordict["Color"][3])
        if result == "Lost in WS":
            colors.append(colordict["Color"][4])
        if result == "Won WS":
            colors.append(colordict["Color"][5])
    fig = px.bar(d, x = "Year", y = "Wins", color = "Result", color_discrete_sequence = colors, title = "Plotting Every " + teamname + " Franchise Season by Wins and Result")
    fig.update_xaxes(categoryorder = "category ascending")
    return fig

# %%
#TBA is rays
#NYA is yankees
#BOS is red sox
#TOR is blue jays
#BAL is orioles

#CLE is guardians
#DET is tigers
#MIN is twins
#KCA is royals

#HOU is astros
#PROBLEM OAK
#PROBLEM LAA
#TEX is rangers
#SEA is seattle

#CHN is cubs
#PROBLEM MIL (only shows them post league switch)
#PIT is pirates
#CIN is reds
#SLN is cardinals

#ARI is diamondbacks
#SFN is giants
#LAN is dodgers
#COL is rockies
#SDN is padres

#NYN is mets
#ATL is braves
#PROBLEM MIA
#PHI is philadelphia
#WSN is washington

#it works for teams that have not relocated.

fig = create("HOU", "Houston Astros")
fig.show()
pio.write_image(fig, 'image.jpg',scale=6, width=1000, height=500)
# Out:
# <div>                            <div id="4dacae69-fac3-4fa3-aaf7-9258958f43ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4dacae69-fac3-4fa3-aaf7-9258958f43ac")) {                    Plotly.newPlot(                        "4dacae69-fac3-4fa3-aaf7-9258958f43ac",                        [{"alignmentgroup":"True","hovertemplate":"Result=Missed Playoffs<br>Year=%{x}<br>Wins=%{y}<extra></extra>","legendgroup":"Missed Playoffs","marker":{"color":"rgba(0, 0, 0, 1)","pattern":{"shape":""}},"name":"Missed Playoffs","offsetgroup":"Missed Playoffs","orientation":"v","showlegend":true,"textposition":"auto","x":[1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1982,1983,1984,1985,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,2000,2002,2003,2006,2007,2008,2009,2010,2011,2012,2013,2014,2016],"xaxis":"x","y":[64,66,66,65,72,69,72,81,79,79,84,82,81,64,80,81,74,89,93,77,85,80,83,76,82,86,75,65,81,85,66,76,82,72,84,87,82,73,86,74,76,56,55,51,70,84],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Result=Lost in DS<br>Year=%{x}<br>Wins=%{y}<extra></extra>","legendgroup":"Lost in DS","marker":{"color":"rgba(120, 125, 55, 1)","pattern":{"shape":""}},"name":"Lost in DS","offsetgroup":"Lost in DS","orientation":"v","showlegend":true,"textposition":"auto","x":[1981,1997,1998,1999,2001,2015],"xaxis":"x","y":[61,84,102,97,93,86],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Result=Lost in CS<br>Year=%{x}<br>Wins=%{y}<extra></extra>","legendgroup":"Lost in CS","marker":{"color":"rgb(205, 127, 50)","pattern":{"shape":""}},"name":"Lost in CS","offsetgroup":"Lost in CS","orientation":"v","showlegend":true,"textposition":"auto","x":[1986,2004,2018,2020],"xaxis":"x","y":[96,92,103,29],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Result=Lost in WS<br>Year=%{x}<br>Wins=%{y}<extra></extra>","legendgroup":"Lost in WS","marker":{"color":"rgba(150, 150, 150, 1)","pattern":{"shape":""}},"name":"Lost in WS","offsetgroup":"Lost in WS","orientation":"v","showlegend":true,"textposition":"auto","x":[2005,2019,2021],"xaxis":"x","y":[89,107,95],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Result=Won WS<br>Year=%{x}<br>Wins=%{y}<extra></extra>","legendgroup":"Won WS","marker":{"color":"rgba(255, 216, 0, 1)","pattern":{"shape":""}},"name":"Won WS","offsetgroup":"Won WS","orientation":"v","showlegend":true,"textposition":"auto","x":[2017],"xaxis":"x","y":[101],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0 ...
